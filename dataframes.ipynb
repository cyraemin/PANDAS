# %%
import numpy as np
import pandas as pd
#when you combine series together,that is referred to as dataframes

# %%
#1.creating dataframe
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2=pd.DataFrame(data_list)
df2
columns=["Name","Age","City","Salary"]
df2=pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#2.selection and indexing of columns
#to select one col-
df2[["Age"]]
# Out:
#    Age
# 0   28
# 1   34
# 2   29
# 3   42

# %%
#to select more than one columns,make list of list
df2[["Age","City"]]
# Out:
#    Age      City
# 0   28  New York
# 1   34     Paris
# 2   29    Berlin
# 3   42    London

# %%
#making new col-
df2["Food"]=["Apple","Banana","Mango","Orange"]
df2
# Out:
#     Name  Age      City  Salary    Food
# 0   John   28  New York   65000   Apple
# 1   Anna   34     Paris   70000  Banana
# 2  Peter   29    Berlin   62000   Mango
# 3  Linda   42    London   85000  Orange

# %%
#3. remove a col or more than 1 col
df2.drop(["Food"],axis=1,inplace=True)#use the inplace keyword,otherwise only copy is returned and not actually deleted
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 #3. remove a col or more than 1 col
# ----> 2 df2.drop(["Food"],axis=1,inplace=True)#use the inplace keyword,otherwise only copy is returned and not actually deleted
#       3 df2
#
# File c:\Users\sxdle\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
#4.selecting row
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
#selecting subset of rows and columns
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
#conditional selection
df2[(df2["Age"]>30)&(df2["City"]=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
